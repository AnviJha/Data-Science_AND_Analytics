# %%
#multiple series together is known as dataframe 
import numpy as np 
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#using list 

data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

# %%
df2= pd.DataFrame(data_list)
col=["name" , "age" , "city","salary"] # manually have to set data 
df2 = pd.DataFrame(data_list , columns = col)

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#Selection and indexing of column 
df2[["name" ,"city"]] # we need to provide list of list for multiple column
# Out:
#     name      city
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
df2["name"]
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: name, dtype: str

# %%
#Creating a new column 
df2["Designation"] = ["doc" , "eng" , "arc" , "eng"]

# %%
df2
# Out:
#     name  age      city  salary Designation
# 0   John   28  New York   65000         doc
# 1   Anna   34     Paris   70000         eng
# 2  Peter   29    Berlin   62000         arc
# 3  Linda   42    London   85000         eng

# %%
#remove a column 
# df2.drop("Designation")#it wont work as bydefault axis is zero 
df2.drop('Designation' , axis=1)
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
#disgnation is not deleted ?!
# Out:
#     name  age      city  salary Designation
# 0   John   28  New York   65000         doc
# 1   Anna   34     Paris   70000         eng
# 2  Peter   29    Berlin   62000         arc
# 3  Linda   42    London   85000         eng

# %%
df2.drop('Designation' , axis=1  , inplace=True)#this will delete the column permanently

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.drop(["city" , "salary"] , axis=1) #for multiple column at once
# Out:
#     name  age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %%
#for row 
df2.drop(1 , axis=0)
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#selecting Rows 
df2.loc[0] #loc means location use for rows
# Out:
# name          John
# age             28
# city      New York
# salary       65000
# Name: 0, dtype: object

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#multiple rows

# %%
df2.loc[[1,2]]
# Out:
#     name  age    city  salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000

# %%
#index location
df.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %%
# particular portion 
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'City', 'Salary'], dtype='str')

# %%
df.loc[[2,3]][["Name" , "Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %%
#conditional selection 
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#age>30 only 
df2[df2["age"]>30]
# Out:
#     name  age    city  salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#Age>30 and city =paris
df2[(df2["age"]>30 )& (df2["city"]=="Paris") ]
# Out:
#    name  age   city  salary
# 1  Anna   34  Paris   70000
