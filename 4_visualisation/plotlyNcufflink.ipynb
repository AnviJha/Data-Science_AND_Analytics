# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# Requirement already satisfied: plotly in C:\Users\ASUS\anaconda3\Lib\site-packages (6.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\ASUS\anaconda3\Lib\site-packages (from plotly) (2.23.0)
# Requirement already satisfied: packaging in C:\Users\ASUS\anaconda3\Lib\site-packages (from plotly) (26.0)
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.9.2 in C:\Users\ASUS\anaconda3\Lib\site-packages (from cufflinks) (2.4.6)
# Requirement already satisfied: pandas>=0.19.2 in C:\Users\ASUS\anaconda3\Lib\site-packages (from cufflinks) (3.0.3)
# Requirement already satisfied: plotly>=4.1.1 in C:\Users\ASUS\anaconda3\Lib\site-packages (from cufflinks) (6.7.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\ASUS\anaconda3\Lib\site-packages (from cufflinks) (1.17.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading colorlover-0.3.0-py3-none-any.whl.metadata (421 bytes)
# Requirement already satisfied: setuptools>=34.4.1 in C:\Users\ASUS\anaconda3\Lib\site-packages (from cufflinks) (83.0.0)
# Requirement already satisfied: ipython>=5.3.0 in C:\Users\ASUS\anaconda3\Lib\site-packages (from cufflinks) (9.15.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in C:\Users\ASUS\anaconda3\Lib\site-packages (from cufflinks) (8.1.7)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipython>=5.3.0->cufflinks) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.52)
# Requirement already satisfied: psutil>=7 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipython>=5.3.0->cufflinks) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipython>=5.3.0->cufflinks) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipython>=5.3.0->cufflinks) (5.15.0)
# Requirement already satisfied: wcwidth in C:\Users\ASUS\anaconda3\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.8.2)
# Requirement already satisfied: comm>=0.1.3 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in C:\Users\ASUS\anaconda3\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\ASUS\anaconda3\Lib\site-packages (from jedi>=0.18.2->ipython>=5.3.0->cufflinks) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ASUS\anaconda3\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\ASUS\anaconda3\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2026.2)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\ASUS\anaconda3\Lib\site-packages (from plotly>=4.1.1->cufflinks) (2.23.0)
# Requirement already satisfied: packaging in C:\Users\ASUS\anaconda3\Lib\site-packages (from plotly>=4.1.1->cufflinks) (26.0)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\ASUS\anaconda3\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\ASUS\anaconda3\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.1)
# Requirement already satisfied: pure_eval in C:\Users\ASUS\anaconda3\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)
# Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (pyproject.toml): started
#   Building wheel for cufflinks (pyproject.toml): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68561 sha256=282abff5a1f3a2598c851991fc0834e83c8f13b8c119bb24c37c21fa9841a0d1
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\e4\0d\21\3611484024347032ee330271868478a2c28877581eb01f9b79
# Successfully built cufflinks
# Installing collected packages: colorlover, cufflinks
#
#    -------------------- ------------------- 1/2 [cufflinks]
#    ---------------------------------------- 2/2 [cufflinks]
#
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3

# %%
import seaborn as sns 
import pandas as pd 
import cufflinks as cf 
from plotly.offline import iplot

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#iplot
#cf is not working properly 
import plotly.express as px #direct interaction with plotly

fig = px.histogram(tips, x='total_bill')
fig.show()
